# %%
cd Documents/
# Out:
# C:\Users\Joe\Documents

# %%
cd "Python progs"
# Out:
# C:\Users\Joe\Documents\Python progs

# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
import lstm, time #helper libraries
# Out:
# Using TensorFlow backend.

# %%
#Step 1 Load Data
X_train, y_train, X_test, y_test = lstm.load_data('sp500.csv', 50, True)

# %%
#Step 2 Build Model
model = Sequential()

model.add(LSTM(
    input_dim=1,
    output_dim=50,
    return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(
    100,
    return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(
    output_dim=1))
model.add(Activation('linear'))

start = time.time()
model.compile(loss='mse', optimizer='rmsprop')
print('compilation time : ', time.time() - start)
# Out:
# compilation time :  0.034001827239990234

# %%
#Step 3 Train the model
model.fit(
    X_train,
    y_train,
    batch_size=512,
    nb_epoch=1,
    validation_split=0.05)
# Out:
# Train on 3523 samples, validate on 186 samples
# Epoch 1/1
# 3523/3523 [==============================] - 8s - loss: 0.0024 - val_loss: 6.7792e-04

# %%
#Step 4 - Plot the predictions!
predictions = lstm.predict_sequences_multiple(model, X_test, 50, 50)
lstm.plot_results_multiple(predictions, y_test, 50)
# Out:
# yo

# %%
#Step 3 Train the model
model.fit(
    X_train,
    y_train,
    batch_size=512,
    nb_epoch=1,
    validation_split=0.05)
# Out:
# Train on 3523 samples, validate on 186 samples
# Epoch 1/1
# 3523/3523 [==============================] - 7s - loss: 6.8282e-04 - val_loss: 8.0697e-04

# %%
#Step 4 - Plot the predictions!
predictions = lstm.predict_sequences_multiple(model, X_test, 50, 50)
lstm.plot_results_multiple(predictions, y_test, 50)
# Out:
# yo

# %%
#Step 3 Train the model
model.fit(
    X_train,
    y_train,
    batch_size=512,
    nb_epoch=1,
    validation_split=0.05)
# Out:
# Train on 3523 samples, validate on 186 samples
# Epoch 1/1
# 3523/3523 [==============================] - 6s - loss: 6.7297e-04 - val_loss: 6.1159e-04

# %%
#Step 4 - Plot the predictions!
predictions = lstm.predict_sequences_multiple(model, X_test, 50, 50)
lstm.plot_results_multiple(predictions, y_test, 50)
# Out:
# yo

# %%
#Step 3 Train the model
model.fit(
    X_train,
    y_train,
    batch_size=1024,
    nb_epoch=1,
    validation_split=0.05)
# Out:
# Train on 3523 samples, validate on 186 samples
# Epoch 1/1
# 3523/3523 [==============================] - 7s - loss: 6.7142e-04 - val_loss: 5.2467e-04

# %%
#Step 4 - Plot the predictions!
predictions = lstm.predict_sequences_multiple(model, X_test, 50, 50)
lstm.plot_results_multiple(predictions, y_test, 50)
# Out:
# yo

# %%
#Step 3 Train the model
model.fit(
    X_train,
    y_train,
    batch_size=1024,
    nb_epoch=2,
    validation_split=0.05)
# Out:
# Train on 3523 samples, validate on 186 samples
# Epoch 1/2
# 3523/3523 [==============================] - 7s - loss: 5.6430e-04 - val_loss: 4.8835e-04
# Epoch 2/2
# 3523/3523 [==============================] - 7s - loss: 4.8414e-04 - val_loss: 5.9489e-04

# %%
#Step 4 - Plot the predictions!
predictions = lstm.predict_sequences_multiple(model, X_test, 50, 50)
lstm.plot_results_multiple(predictions, y_test, 50)
# Out:
# yo
